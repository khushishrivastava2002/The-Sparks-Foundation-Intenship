# %% [markdown]
# ### The Sparks Foundation - Data Science & Business Analytics Intership

# %% [markdown]
# ### Task 3 -  Exploratory Data Analysis_Retail
#
#
#         1) Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#         2) As a business manager, try to find out the weak areas where you can work to make more profit.
#         3) What all business problems you can derive by exploring the data?
#         4) I used Python to perform EDA on this dataset.
#         5) Dataset: https://bit.ly/3i4rbWl

# %%
#importing essential Libaries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %% [markdown]
# ## 1) Understanding The Data

# %%
df.sample(5)
# Out:
#            Ship Mode    Segment        Country           City       State  \
# 3896  Standard Class  Corporate  United States    San Antonio       Texas
# 8012        Same Day   Consumer  United States  New York City    New York
# 5417    Second Class  Corporate  United States          Omaha    Nebraska
# 1372    Second Class   Consumer  United States        Vallejo  California
# 2110        Same Day   Consumer  United States       Redlands  California
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 3896        78207  Central  Office Supplies    Fasteners    3.552         3
# 8012        10009     East  Office Supplies      Binders  663.920         5
# 5417        68104  Central  Office Supplies      Binders   15.360         2
# 1372        94591     West  Office Supplies       Labels   29.600         2
# 2110        92374     West  Office Supplies    Fasteners   17.450         5
#
#       Discount    Profit
# 3896       0.2    1.2432
# ...

# %%
#First 10 records
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
#last 10 records
df.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
#return the object type which is dataframe

type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 2) Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#count the unique values
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# ##### Cleaning the data set

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#detecting duplicate Value
df[df.duplicated(subset=None, keep=False)]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 568   Standard Class    Corporate  United States        Seattle    Washington
# 591   Standard Class     Consumer  United States          Salem        Oregon
# 935   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 1186  Standard Class    Corporate  United States        Seattle    Washington
# 1479  Standard Class     Consumer  United States  San Francisco    California
# 2803  Standard Class     Consumer  United States  San Francisco    California
# 2807    Second Class     Consumer  United States        Seattle    Washington
# 2836  Standard Class     Consumer  United States    Los Angeles    California
# 3127  Standard Class     Consumer  United States  New York City      New York
# 3405  Standard Class  Home Office  United States       Columbus          Ohio
# ...

# %%
#droping the duplicate records
df=pd.DataFrame.drop_duplicates(df)
df.shape
# Out:
# (9944, 12)

# %%
#Corelation Matrix
sns.heatmap(df.corr(),cmap= 'PuBu',annot= True)
plt.show()

# %%
sns.pairplot(df,hue="Ship Mode")

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5930
# Second Class      1941
# First Class       1531
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=df['Ship Mode'])
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
#value counts for segment
df['Segment'].value_counts()
# Out:
# Consumer       5160
# Corporate      3008
# Home Office    1776
# Name: Segment, dtype: int64

# %%
#plotting pair plot
sns.pairplot(df,hue='Segment')

# %%
sns.countplot(x='Segment',data=df,palette="tab10")
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1518
# Paper          1344
# Furnishings     954
# Phones          888
# Storage         845
# Art             793
# Accessories     773
# Chairs          615
# Appliances      466
# Labels          359
# Tables          319
# Envelopes       254
# Bookcases       226
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
sns.pairplot(df,hue='Category')

# %%
plt.figure(figsize=(15,12))
df['Sub-Category'].value_counts().plot.pie(autopct='dark')
plt.show()

# %% [markdown]
# ## Observation-1
#
# #### Maximun are from Binders,Paper,funishings,phones,storage,art,accessories and minimum from copiers,machines,suppliers.

# %%
df['State'].value_counts()
# Out:
# California              1980
# New York                1119
# Texas                    980
# Pennsylvania             581
# Washington               502
# Illinois                 490
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,palette='rocket_r',order=df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Observation-2
#
# #### Highest Number of buyers are from Callifornia and New York

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# ## Observation-3
#
#        . Most customer Tend to buy Quantity of 2 and 3
#        . Discount give maximum  is 0 to 20 percent

# %%
plt.figure(figsize=(10,8))
df['Region'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### PROFIT VS DISCOUNT

# %%
fig,ax=plt.subplots(figsize=(20,8))
ax.scatter(df['Sales'],df['Profit'])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %%
sns.lineplot(x='Discount',y='Profit',label='Profit',data=df)
plt.legend()
plt.show()

# %% [markdown]
# ## observation 4
#
# #### No corelation Between  profit and Discount

# %%
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=df)
plt.legend()
plt.show()

# %%
df.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['pink','blue'],figsize=(8,5))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ## Observation 5
#
# #### Profit and sales are maximum in cosumer segment and minimum in Home Office segment

# %%
plt.figure(figsize=(12,8))
plt.title('Segment Wise sales in Each region')
sns.barplot(x='Region',y='Sales',data=df,hue='Segment',order=df['Region'].value_counts().index,palette='rocket')
plt.xlabel('Region',fontsize=15)
plt.show()

# %% [markdown]
# ## Observation 6
#
# #### Segment wise sales are almost same in every region

# %%
df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ## Observation 7
#
# #### Profit and Sales are maximum it west region and Maximum in south region

# %%
ps=df.groupby('State')[['Sales','Profit']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ## Observation 8
#
#     . high profit for california, new York
#     . loss is for texas, pennysulvania, ohio

# %%
t_states=df['State'].value_counts().nlargest(10)
t_states
# Out:
# California        1980
# New York          1119
# Texas              980
# Pennsylvania       581
# Washington         502
# Illinois           490
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %%
ps=df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['yellow','purple'],figsize=(8,5))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ## Observation 9
#
#     . As a business manager,try to find out week areas where you can work to make more profit?
#     . Technology and office Supplies have high Profit
#     . Furniture have less profit

# %%
ps=df.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['red','lightblue'],figsize=(15,8))
plt.title('Profit/loss &Sales across States')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %% [markdown]
# ## Observation 10
#
#     . Phone  sub-category have high sales
#     . chairs have high sales but less profit compared to phones.
#     . Tables and Bookmarks sub-category facing huge loss.

# %% [markdown]
# ## Thank You:))
